# %%
name=input("enter name : ")
cur_age=int(input("enter age : "))
age=cur_age+1
print(f"hello {name}")
print(f"happy birthday, now you are {age} year old")
# Out:
# enter name :  dev
# enter age :  18
# hello dev
# happy birthday, now you are 19 year old
