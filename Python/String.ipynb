# %% [markdown]
# # String

# %%
str1="I am Arun Bharti"

#get any string character via index 

print(str1[2:4])
# Out:
# am

# %%
print(str1[:9])
# Out:
# I am Arun

# %%
print(str1[10:])
# Out:
# Bharti

# %%
Big_str='''hey!
How are you'''
print(Big_str)
# Out:
# hey!
# How are you

# %% [markdown]
# # String Functions

# %%
strr="Python is an programminng language"

# %%
strr.upper()
# Out:
# 'PYTHON IS AN PROGRAMMINNG LANGUAGE'

# %%
strr.lower()
# Out:
# 'python is an programminng language'

# %%
strr.count('i')
# Out:
# 2

# %%
strr.find('P') #finds the index value.
# Out:
# 0

# %%
strr.index('P') #it is also used to find the index value.
# Out:
# 0

# %%
strr.replace("Python","C")
# Out:
# 'C is an programminng language'

# %%
print(strr.split(" ")) #to convert string into list via use space or any other as spliter.
# Out:
# ['Python', 'is', 'an', 'programminng', 'language']

# %%
print(strr.rpartition(" an ")) #to convert string into tuple.
# Out:
# ('Python is', ' an ', 'programminng language')

# %% [markdown]
# # String Concatenation

# %%
str11="Good"
str22="Morning"

# %%
print(str11+" "+str22) #method-1
# Out:
# Good Morning

# %%
print("{} {}".format(str11,str22)) #method-2
# Out:
# Good Morning
