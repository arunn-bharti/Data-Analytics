# %% [markdown]
# # Dictionary

# %%
d1={} #Dictionary is unordered.
type(d1)
# Out:
# dict

# %%
d2={1:"Maths",2:"Python",3:"Java"}
d2
# Out:
# {1: 'Maths', 2: 'Python', 3: 'Java'}

# %%
list=[("a","arun"),("b","bharti")] #creating a dictionary from a list
d3=dict(list)
d3
# Out:
# {'a': 'arun', 'b': 'bharti'}

# %% [markdown]
# # Another way to create a dictionary

# %%
keys={1,2,3,4}
value="ID"
dict.fromkeys(keys,value)
# Out:
# {1: 'ID', 2: 'ID', 3: 'ID', 4: 'ID'}

# %% [markdown]
# # Nesting dictionary

# %%
nest_dic={"name":{"first":"Arun","last":"Bharti"},"age":20,"year":2025}
nest_dic
# Out:
# {'name': {'first': 'Arun', 'last': 'Bharti'}, 'age': 20, 'year': 2025}

# %% [markdown]
# # Adding elements

# %%
d={}

# %%
d["name"]={"first":"Rahul","last":"Singh"}
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'}}

# %%
d["age"]=18
d["group"]='a'
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'}, 'age': 18, 'group': 'a'}

# %%
d["age"]=20 #update element's value.
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'}, 'age': 20, 'group': 'a'}

# %% [markdown]
# # Accessing elements

# %%
print(d["name"]["first"]) #method-1
# Out:
# Rahul

# %%
print(d.get("age")) #method-2
# Out:
# 20

# %% [markdown]
# # Deleting elements

# %%
d["year"]=2025
d["city"]='ahemdabad'
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'},
#  'age': 20,
#  'group': 'a',
#  'year': 2025,
#  'city': 'ahemdabad'}

# %%
d.pop("year") #this method to delete a specific key-value.
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'},
#  'age': 20,
#  'group': 'a',
#  'city': 'ahemdabad'}

# %%
d.popitem() #this method deletes the last item of dictionary
d
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'}, 'age': 20, 'group': 'a'}

# %% [markdown]
# # Functions

# %%
d.items() #to print all keys and values
# Out:
# dict_items([('name', {'first': 'Rahul', 'last': 'Singh'}), ('age', 20), ('group', 'a')])

# %%
d.keys() #to print all keys only
# Out:
# dict_keys(['name', 'age', 'group'])

# %%
d.values() #to print all values only
# Out:
# dict_values([{'first': 'Rahul', 'last': 'Singh'}, 20, 'a'])

# %%
d.get("age") #to print any particular key's value only
# Out:
# 20

# %%
c=d.copy()
print(c)
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'}, 'age': 20, 'group': 'a'}

# %%
c.setdefault("batch",2)
c.setdefault("batch",1) #if key have values, then it will never change the value "note:use update function"
c
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'},
#  'age': 20,
#  'group': 'a',
#  'batch': 1}

# %%
c.update({"batch":1}) #to update key-values
c
# Out:
# {'name': {'first': 'Rahul', 'last': 'Singh'},
#  'age': 20,
#  'group': 'a',
#  'batch': 1}

# %%
d.clear()

# %% [markdown]
# # Dictionary Problems

# %%
#print values in sorted form
D={"NAME":"ARUN","COURSE":"MCA","YEAR":"2025"}
sorted(D.values())
# Out:
# ['2025', 'ARUN', 'MCA']

# %%
di={}
for i in range(1,16):
    di[i]=i*i             #i**2
print(di)
type(di)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
# dict

# %%
#to mulltiply all values of dictionary
dw={"a":1,"b":2,"c":5}
mul=1
for i in dw.values():
    mul*=i
print(mul)
# Out:
# 10

# %%
x=sorted(D.keys())
x
# Out:
# ['COURSE', 'NAME', 'YEAR']
