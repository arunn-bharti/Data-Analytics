# %% [markdown]
# # Sets

# %%
s1={1,2,1,4,5,7} #set values not duplicated. and it will arranged automatically.
print(s1)
type(s1)
# Out:
# {1, 2, 4, 5, 7}
# set

# %%
s1.add(9)
s1
# Out:
# {1, 2, 4, 5, 7, 9}

# %%
frozenset2=frozenset({11,12,13,14})
frozenset2
# Out:
# frozenset({11, 12, 13, 14})

# %%
frozenset2.add(15) #frozenset can't be changeable.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 frozenset2.add(15)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s1
# Out:
# {1, 2, 4, 5, 7, 9}

# %%
s2={7,6,2,3,10}
s2
# Out:
# {2, 3, 6, 7, 10}

# %%
s1.union(s2) #all combined values
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 10}

# %%
s1.difference(s2) #different values
# Out:
# {1, 4, 5, 9}

# %%
s1.intersection(s2) #common value
# Out:
# {2, 7}
