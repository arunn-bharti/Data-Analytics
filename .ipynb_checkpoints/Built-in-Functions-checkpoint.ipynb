# %%
#Functions

# %%
x=-23.45
abs(x)
# Out:
# 23.45

# %%
round(x)
# Out:
# -23

# %%
max(1,2,3,4,5)
# Out:
# 5

# %%
min(1,2,3,4,5)
# Out:
# 1

# %%
#Math functions

# %%
import math
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.exp(2) #here 2 is the power of e: is stored value by math function
# Out:
# 7.38905609893065

# %%
math.sqrt(49)
# Out:
# 7.0
