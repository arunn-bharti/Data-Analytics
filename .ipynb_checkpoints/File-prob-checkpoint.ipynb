# %%
f=open("data.txt",'x')

# %%
f=open("data.txt",'w')
w=f.write("Arun\nMCA\n2026")
print(w)
# Out:
# 13

# %%
f=open("data.txt",'r')
r=f.read()
print(r)
# Out:
# Arun
# MCA
# 2026

# %%
f=open("data.txt",'r')
r=f.readline()
print(r)
# Out:
# Arun

# %%
f=open("data.txt",'r')
r=f.readlines()
print(r)
# Out:
# ['Arun\n', 'MCA\n', '2026']

# %%
f=open("data.txt",'r')
r=f.read()
s=r.split()
len(s)
# Out:
# 3

# %%
f=open("data.txt",'a')
w=f.write("\nAIT")
print(w)
# Out:
# 4

# %%
f=open("data.txt",'r')
r=f.read()

#copy file

f2=open("A11.txt",'a')
z=f2.write(r)
print(z)
# Out:
# 21

# %%
f=open("data.txt",'r')
r=f.read()
if "Arun" in r:
    print("Arun")
else:
    print("nothing")
# Out:
# Arun

# %%
f=open("data.txt",'r')
r=f.read()
c=len(r)
c
# Out:
# 21

# %%
f=open("data.txt",'r')
r=f.read()
char=len(r)
wd=r.split()
word=len(s)
print(word)
print(char)
# Out:
# 1
# 21

# %%
f=open("data.txt",'r')
count=0
for line in f:
    count+=1
print(count)
# Out:
# 5
