# %% [markdown]
# # Array

# %%
from array import *
arr=array('i',[])
x=int(input("enter size of array : "))
print("enter %d numbers :  ",x)

for i in range(x):
    n=int(input())
    arr.append(n)
print(arr)
# Out:
# enter size of array :  3
# enter %d numbers :   3
#  1
#  2
#  3
# array('i', [1, 2, 3])
