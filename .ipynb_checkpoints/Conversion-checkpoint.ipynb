# %%
a="24"
type(a)
# Out:
# str

# %%
a=int(a)
print(a)
type(a)
# Out:
# 24
# int

# %%
a=float(a)
print(a)
type(a)
# Out:
# 24.0
# float

# %%
a=complex(a)
print(a)
type(a)
# Out:
# (24+2j)
# complex

# %%
a=complex(complex(a),5)
print(a)
type(a)
# Out:
# (24+7j)
# complex
