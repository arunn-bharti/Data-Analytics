# %%
def talk():
    print("hello")

talk() #call function
# Out:
# hello

# %%
def add(a,b):
    return a+b

add(20,1)
# Out:
# 21

# %%
def add(a,b=45): #default parameters
    return a+b

add(10)
# Out:
# 55

# %%
def add(a,b):
    return a+b

print(add(2,3))
print(add(15,16))
# Out:
# 5
# 31
