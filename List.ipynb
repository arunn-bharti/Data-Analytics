# %% [markdown]
# # List

# %%
ls=[1,"hy","arun",4,"five",6]
print(ls)
# Out:
# [1, 'hy', 'arun', 4, 'five', 6]

# %%
type(ls)
# Out:
# list

# %%
print(ls[2])
# Out:
# arun

# %%
list1[3]=10
print(ls)
# Out:
# [1, 'hy', 'arun', 4, 'five', 6]

# %%
print(ls[:3])
# Out:
# [1, 'hy', 'arun']

# %%
print(ls[1:])
# Out:
# ['hy', 'arun', 4, 'five', 6]

# %%
print(ls[1:2])
# Out:
# ['hy']

# %%
print(ls[1:5:3]) #here 1 is starting index, 5 is ending index and 3 is the print the value after 3 index.
# Out:
# ['hy', 'five']

# %% [markdown]
# # Operations on list

# %%
z=[1]*5
print(z)
# Out:
# [1, 1, 1, 1, 1]

# %%
str=["hey","arun"]
num=[12,18,20]
print(str+num)
# Out:
# ['hey', 'arun', 12, 18, 20]

# %%
string=list("helloworld")
print(string)
# Out:
# ['h', 'e', 'l', 'l', 'o', 'w', 'o', 'r', 'l', 'd']

# %%
subjects=["c","c++","python","java"]
one, *others=subjects
print(one)
print(others)
# Out:
# c
# ['c++', 'python', 'java']

# %% [markdown]
# # Methods on list

# %%
a=[5,6,7,8]
b=["ram","shyam","dev"]

# %%
a.append(9)
print(a)
# Out:
# [5, 6, 7, 8, 9]

# %%
a.extend(b)
print(a)
# Out:
# [5, 6, 7, 8, 9, 'ram', 'shyam', 'dev']

# %%
a.remove("dev") #to remove direct value, it removes the only first occunrence of value. 
print(a)
# Out:
# [5, 6, 7, 8, 9, 'ram', 'shyam']

# %%
a.insert(7,"ved") #for inserting via index we use insert method.
print(a)
# Out:
# [5, 6, 7, 8, 9, 'ram', 'shyam', 'ved']

# %%
even=[8,10,2,6,12]
even.sort()
print(even)
# Out:
# [2, 6, 8, 10, 12]

# %%
r=[1,2,3,4]
r.reverse()
print(r)
# Out:
# [4, 3, 2, 1]

# %%
r.clear() #clear a Li
print(r)
# Out:
# []

# %%
# List comprehention

L1=[1,23,123,5,14]
L2=[i for i in L1 if i>10]
print(L2)
# Out:
# [23, 123, 14]

# %% [markdown]
# # Built-in function of list

# %%
n=[3,7,12,19]

# %%
max(n)
# Out:
# 19

# %%
min(n)
# Out:
# 3

# %%
len(n)
# Out:
# 4

# %%
sum(n)
# Out:
# 41

# %%
avg=sum(n)/len(n)
print(avg)
# Out:
# 10.25

# %% [markdown]
# # List Problems

# %%
a=["Rose","Rachel","Monica","Joe"]

# %%
a[0],a[3]=a[3],a[0]
print(a)
# Out:
# ['Joe', 'Rachel', 'Monica', 'Rose']

# %%
a.insert(1,"Oggy")
a
# Out:
# ['Joe', 'Oggy', 'Rachel', 'Monica', 'Rose']

# %%
a.pop(2)
a
# Out:
# ['Joe', 'Oggy', 'Monica', 'Rose']

# %%
b=[13,7,12,10]

# %%
sum=1
for i in b:
    sum*=i
print(sum)
# Out:
# 10920

# %%
max(b)
# Out:
# 13

# %%
min(b)
# Out:
# 7
