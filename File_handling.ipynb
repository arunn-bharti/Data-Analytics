# %%
f=open("A11.txt","a")

# %%
f=open("A11.txt","w")
a=f.write("Hi Arun\nDept MCA\nYear 2026")
print(a)
# Out:
# 26

# %%
f=open("A11.txt","r")
b=f.read()
print(b)
# Out:
# Hi Arun
# Dept MCA
# Year 2026

# %%
f=open("A11.txt","r")
b=f.readline()
print(b)
# Out:
# Hi Arun

# %%
linesf=open("A11.txt","r")
b=f.readlines()
print(b)
# Out:
# ['Dept MCA\n', 'Year 2026']

# %%
f=open("A11.txt","a")
b=f.write("\nAppend filed")
print(b)
# Out:
# 13

# %%
f=open("A11.txt","r")
b=f.read()
print(b)
# Out:
# Hi Arun
# Dept MCA
# Year 2026
# Append filed

# %%
f.close()

# %%
import os
os.remove("A11.txt")
